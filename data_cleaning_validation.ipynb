# %%
import pandas as pd
from sqlalchemy import create_engine, text

# %%
conn = create_engine('postgresql://root:root@localhost:5432/online_retail')

# %%
df = pd.read_sql('select * from retail_data', con=conn, index_col='Index')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# Index
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# Index
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# # Handling Missing Values

# %% [markdown]
# #### Checking column with null values

# %%
missing_data = df.isnull().sum()

# %%
missing_data
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df[df['Description'].isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# Index
# 2406      536589     21777        None       -10 2010-12-01 16:50:00
# 622       536414     22139        None        56 2010-12-01 11:52:00
# 1970      536545     21134        None         1 2010-12-01 14:32:00
# 1971      536546     22145        None         1 2010-12-01 14:33:00
# 1972      536547     37509        None         1 2010-12-01 14:33:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581        None        -2 2011-12-07 18:26:00
# 535326    581203     23406        None        15 2011-12-07 18:31:00
# 535332    581209     21620        None         6 2011-12-07 18:35:00
# 536981    581234     72817        None        27 2011-12-08 10:33:00
# 538554    581408     85175        None        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country
# Index
# 2406          0.0         NaN  United Kingdom
# 622           0.0         NaN  United Kingdom
# 1970          0.0         NaN  United Kingdom
# 1971          0.0         NaN  United Kingdom
# 1972          0.0         NaN  United Kingdom
# ...           ...         ...             ...
# 535322        0.0         NaN  United Kingdom
# 535326        0.0         NaN  United Kingdom
# 535332        0.0         NaN  United Kingdom
# 536981        0.0         NaN  United Kingdom
# 538554        0.0         NaN  United Kingdom
#
# [1454 rows x 8 columns]

# %% [markdown]
# #### Removing null value in **Description** column

# %%
df = df[df['Description'].notnull()]

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# Index
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# Index
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [540455 rows x 8 columns]

# %% [markdown]
# #### Checking null value in **CustomerID**

# %%
df[df['CustomerID'].isnull()]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# Index
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# 1447      536544     21790               VINTAGE SNAP CARDS         9
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# Index
# 1443   2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1444   2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1445   2010-12-01 14:32:00       0.85         NaN  United Kingdom
# 1446   2010-12-01 14:32:00       1.66         NaN  United Kingdom
# 1447   2010-12-01 14:32:00       1.66         NaN  United Kingdom
# ...                    ...        ...         ...             ...
# 541536 2011-12-09 10:26:00       4.13         NaN  United Kingdom
# 541537 2011-12-09 10:26:00       4.13         NaN  United Kingdom
# 541538 2011-12-09 10:26:00       4.96         NaN  United Kingdom
# 541539 2011-12-09 10:26:00      10.79         NaN  United Kingdom
# 541540 2011-12-09 10:26:00    1714.17         NaN  United Kingdom
#
# [133626 rows x 8 columns]

# %% [markdown]
# #### Checking if InvoiceNo can be used to predict CustomerID since they have relation

# %%
df[df['InvoiceNo'] == '544812']
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# Index
# 100227    544812     21774     DECORATIVE CATS BATHROOM BOTTLE         1
# 100228    544812     21775    DECORATIVE FLORE BATHROOM BOTTLE         1
# 100229    544812     21846       PINK DIAMANTE PEN IN GIFT BOX         1
# 100230    544812     21851      LILAC DIAMANTE PEN IN GIFT BOX         1
# 100231    544812     21864     UNION JACK FLAG PASSPORT COVER          1
# ...          ...       ...                                 ...       ...
# 100439    544812     35241         ENAMEL BLUE RIM BISCUIT BIN         1
# 100440    544812    85123A  WHITE HANGING HEART T-LIGHT HOLDER         1
# 100441    544812     21733    RED HANGING HEART T-LIGHT HOLDER         7
# 100442    544812     22173  METAL 4 HOOK HANGER FRENCH CHATEAU         9
# 100443    544812    82494L         WOODEN FRAME ANTIQUE WHITE         11
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# Index
# 100227 2011-02-23 15:58:00       2.46         NaN  United Kingdom
# 100228 2011-02-23 15:58:00       2.46         NaN  United Kingdom
# 100229 2011-02-23 15:58:00       4.13         NaN  United Kingdom
# 100230 2011-02-23 15:58:00       4.13         NaN  United Kingdom
# 100231 2011-02-23 15:58:00       4.13         NaN  United Kingdom
# ...                    ...        ...         ...             ...
# 100439 2011-02-23 15:58:00       9.96         NaN  United Kingdom
# 100440 2011-02-23 15:58:00       2.95         NaN  United Kingdom
# 100441 2011-02-23 15:58:00       2.95         NaN  United Kingdom
# 100442 2011-02-23 15:58:00       2.95         NaN  United Kingdom
# 100443 2011-02-23 15:58:00       2.95         NaN  United Kingdom
#
# [217 rows x 8 columns]

# %% [markdown]
# #### Removing null value in **CustomerID** since it can not be predicted

# %%
df = df[df['CustomerID'].notnull()]

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# Index
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# Index
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [406829 rows x 8 columns]

# %% [markdown]
# #### Verifying no more missing value

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# # Handling duplicate records

# %% [markdown]
# #### Checking for duplicate records

# %%
df[df.duplicated()]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# Index
# 517       536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527       536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537       536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539       536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555       536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# ...          ...       ...                                ...       ...
# 541675    581538     22068        BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992             REVOLVER WOODEN RULER          1
# 541699    581538     22694                       WICKER STAR          1
# 541701    581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# Index
# 517    2010-12-01 11:45:00       1.25     17908.0  United Kingdom
# 527    2010-12-01 11:45:00       2.10     17908.0  United Kingdom
# 537    2010-12-01 11:45:00       2.95     17908.0  United Kingdom
# 539    2010-12-01 11:45:00       4.95     17908.0  United Kingdom
# 555    2010-12-01 11:49:00       2.95     17920.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541675 2011-12-09 11:34:00       0.39     14446.0  United Kingdom
# 541689 2011-12-09 11:34:00       2.49     14446.0  United Kingdom
# 541692 2011-12-09 11:34:00       1.95     14446.0  United Kingdom
# 541699 2011-12-09 11:34:00       2.10     14446.0  United Kingdom
# 541701 2011-12-09 11:34:00       2.08     14446.0  United Kingdom
#
# [5225 rows x 8 columns]

# %% [markdown]
# #### Dropping duplicate records

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# Index
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# Index
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [401604 rows x 8 columns]

# %% [markdown]
# # Handling Outliers

# %% [markdown]
# ### Checking outlier in **Quantity** column

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df['Quantity'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x231e0366150>,
#   <matplotlib.lines.Line2D at 0x231e03643e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x231e035e690>,
#   <matplotlib.lines.Line2D at 0x231e035cb90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x231e0367f50>],
#  'medians': [<matplotlib.lines.Line2D at 0x231e034edb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x231e034ca70>],
#  'means': []}

# %%
plt.show()

# %% [markdown]
# #### Checking for negative value in **Quantity** Column

# %%
df[df['Quantity'] < 0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# Index
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# Index
# 141    2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154    2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235    2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# ...                    ...        ...         ...             ...
# 540449 2011-12-09 09:57:00       0.83     14397.0  United Kingdom
# 541541 2011-12-09 10:28:00     224.69     15498.0  United Kingdom
# 541715 2011-12-09 11:57:00      10.95     15311.0  United Kingdom
# 541716 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
# 541717 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
#
# [8872 rows x 8 columns]

# %% [markdown]
# #### Removing outliers in **Quantity** Column using **IQR**

# %%
Q1 = df["Quantity"].quantile(0.25)
Q3 = df["Quantity"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df[df["Quantity"].between(lower_bound, upper_bound)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# Index
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# Index
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [374958 rows x 8 columns]

# %% [markdown]
# #### Checking if removing outliers with **IQR** solve negative issue

# %%
df[df['Quantity'] < 0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# Index
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# Index
# 141    2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154    2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235    2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# ...                    ...        ...         ...             ...
# 540449 2011-12-09 09:57:00       0.83     14397.0  United Kingdom
# 541541 2011-12-09 10:28:00     224.69     15498.0  United Kingdom
# 541715 2011-12-09 11:57:00      10.95     15311.0  United Kingdom
# 541716 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
# 541717 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
#
# [8872 rows x 8 columns]

# %% [markdown]
# #### Changing all negative value to Positive with an assumption that its input error Since **IQR** does not solve it

# %%
df.loc[df['Quantity'] < 0, 'Quantity'] = df.loc[df['Quantity'] < 0, 'Quantity'] * -1

# %% [markdown]
# #### Verifying that **Quantity** column does not contain negative value

# %%
df[df['Quantity'] < 0]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# #### Setting all Quantity above 250 to 250

# %%
df.loc[df['Quantity'] > 250, 'Quantity'] = 250

# %% [markdown]
# #### Checking no value above 1000 in Quantity column

# %%
df[df['Quantity'] > 250]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
plt.boxplot(df['Quantity'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x231e01711c0>,
#   <matplotlib.lines.Line2D at 0x231e01639e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x231e01962d0>,
#   <matplotlib.lines.Line2D at 0x231e0162c60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x231e0172b10>],
#  'medians': [<matplotlib.lines.Line2D at 0x231e0160e00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x231e0153470>],
#  'means': []}

# %%
plt.show()

# %% [markdown]
# ### Checking outliers in **UnitPrice** column

# %%
plt.boxplot(df['UnitPrice'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x231e00219a0>,
#   <matplotlib.lines.Line2D at 0x231e0020050>],
#  'caps': [<matplotlib.lines.Line2D at 0x231e001a6c0>,
#   <matplotlib.lines.Line2D at 0x231e00190d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x231e0022570>],
#  'medians': [<matplotlib.lines.Line2D at 0x231e000b740>],
#  'fliers': [<matplotlib.lines.Line2D at 0x231e0009fa0>],
#  'means': []}

# %%
plt.show()

# %% [markdown]
# ### Setting all price above 2000 to 2000

# %%
df.loc[df['UnitPrice'] > 2000, 'UnitPrice'] = 2000.00

# %% [markdown]
# ### Verifying no outlier in **UnitPrice** Column

# %%
df.loc[df['UnitPrice'] > 2000.00, :]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# # Handling  Consistency and Integrity

# %% [markdown]
# ### Making sure **InvoiceNo** column meets the rule: Invoice number. Nominal, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation

# %%
df.loc[:,'Valid_InvoiceNo'] = df['InvoiceNo'].apply(lambda x: x.isdigit() and len(x) == 6 or x.startswith('C'))

df = df[df['Valid_InvoiceNo']]
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24248\1247226603.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'Valid_InvoiceNo'] = df['InvoiceNo'].apply(lambda x: x.isdigit() and len(x) == 6 or x.startswith('C'))
#        InvoiceNo StockCode                          Description  Quantity  \
# Index
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# Index
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
#         Valid_InvoiceNo
# Index
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# ...                 ...
# 541904             True
# 541905             True
# 541906             True
# 541907             True
# 541908             True
#
# [401604 rows x 9 columns]

# %% [markdown]
# ### Making sure **StockCode** column meet the rule: Product (item) code. Nominal, a 5-digit integral number uniquely assigned to each distinct product.

# %%
df.loc[:,'Valid_StockCode'] = df['StockCode'].apply(lambda x: x.isdigit() and len(x) == 5)
df = df[df['Valid_StockCode']]
df
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# Index
# 1         536365     71053                WHITE METAL LANTERN         6
# 5         536365     22752       SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730  GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633             HAND WARMER UNION JACK         6
# 8         536366     22632          HAND WARMER RED POLKA DOT         6
# ...          ...       ...                                ...       ...
# 541904    581587     22613        PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899       CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254      CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255    CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138      BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# Index
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 5      2010-12-01 08:26:00       7.65     17850.0  United Kingdom
# 6      2010-12-01 08:26:00       4.25     17850.0  United Kingdom
# 7      2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 8      2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
#         Valid_InvoiceNo  Valid_StockCode
# Index
# 1                  True             True
# 5                  True             True
# 6                  True             True
# 7                  True             True
# 8                  True             True
# ...                 ...              ...
# 541904             True             True
# 541905             True             True
# 541906             True             True
# 541907             True             True
# 541908             True             True
#
# [366179 rows x 10 columns]

# %% [markdown]
# ### Making sure CustomerID meet rule: Customer number. Nominal, a 5-digit integral number uniquely assigned to each customer

# %%
df['CustomerID'] = df['CustomerID'].astype(int)
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24248\579924671.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CustomerID'] = df['CustomerID'].astype(int)
#        InvoiceNo StockCode                        Description  Quantity  \
# Index
# 1         536365     71053                WHITE METAL LANTERN         6
# 5         536365     22752       SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730  GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633             HAND WARMER UNION JACK         6
# 8         536366     22632          HAND WARMER RED POLKA DOT         6
# ...          ...       ...                                ...       ...
# 541904    581587     22613        PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899       CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254      CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255    CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138      BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# Index
# 1      2010-12-01 08:26:00       3.39       17850  United Kingdom
# 5      2010-12-01 08:26:00       7.65       17850  United Kingdom
# 6      2010-12-01 08:26:00       4.25       17850  United Kingdom
# 7      2010-12-01 08:28:00       1.85       17850  United Kingdom
# 8      2010-12-01 08:28:00       1.85       17850  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85       12680          France
# 541905 2011-12-09 12:50:00       2.10       12680          France
# 541906 2011-12-09 12:50:00       4.15       12680          France
# 541907 2011-12-09 12:50:00       4.15       12680          France
# 541908 2011-12-09 12:50:00       4.95       12680          France
#
#         Valid_InvoiceNo  Valid_StockCode
# Index
# 1                  True             True
# 5                  True             True
# 6                  True             True
# 7                  True             True
# 8                  True             True
# ...                 ...              ...
# 541904             True             True
# 541905             True             True
# 541906             True             True
# 541907             True             True
# 541908             True             True
#
# [366179 rows x 10 columns]

# %%
df.loc[:,'Valid_CustomerID'] = df['CustomerID'].apply(lambda x: str(x).isdigit() and len(str(x)) == 5)
df = df[df['Valid_CustomerID']]
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24248\3603662782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'Valid_CustomerID'] = df['CustomerID'].apply(lambda x: str(x).isdigit() and len(str(x)) == 5)
#        InvoiceNo StockCode                        Description  Quantity  \
# Index
# 1         536365     71053                WHITE METAL LANTERN         6
# 5         536365     22752       SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730  GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633             HAND WARMER UNION JACK         6
# 8         536366     22632          HAND WARMER RED POLKA DOT         6
# ...          ...       ...                                ...       ...
# 541904    581587     22613        PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899       CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254      CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255    CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138      BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# Index
# 1      2010-12-01 08:26:00       3.39       17850  United Kingdom
# 5      2010-12-01 08:26:00       7.65       17850  United Kingdom
# 6      2010-12-01 08:26:00       4.25       17850  United Kingdom
# 7      2010-12-01 08:28:00       1.85       17850  United Kingdom
# 8      2010-12-01 08:28:00       1.85       17850  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85       12680          France
# 541905 2011-12-09 12:50:00       2.10       12680          France
# 541906 2011-12-09 12:50:00       4.15       12680          France
# 541907 2011-12-09 12:50:00       4.15       12680          France
# 541908 2011-12-09 12:50:00       4.95       12680          France
#
#         Valid_InvoiceNo  Valid_StockCode  Valid_CustomerID
# Index
# 1                  True             True              True
# 5                  True             True              True
# 6                  True             True              True
# 7                  True             True              True
# 8                  True             True              True
# ...                 ...              ...               ...
# 541904             True             True              True
# 541905             True             True              True
# 541906             True             True              True
# 541907             True             True              True
# 541908             True             True              True
#
# [366179 rows x 11 columns]

# %%
df
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# Index
# 1         536365     71053                WHITE METAL LANTERN         6
# 5         536365     22752       SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730  GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633             HAND WARMER UNION JACK         6
# 8         536366     22632          HAND WARMER RED POLKA DOT         6
# ...          ...       ...                                ...       ...
# 541904    581587     22613        PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899       CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254      CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255    CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138      BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# Index
# 1      2010-12-01 08:26:00       3.39       17850  United Kingdom
# 5      2010-12-01 08:26:00       7.65       17850  United Kingdom
# 6      2010-12-01 08:26:00       4.25       17850  United Kingdom
# 7      2010-12-01 08:28:00       1.85       17850  United Kingdom
# 8      2010-12-01 08:28:00       1.85       17850  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85       12680          France
# 541905 2011-12-09 12:50:00       2.10       12680          France
# 541906 2011-12-09 12:50:00       4.15       12680          France
# 541907 2011-12-09 12:50:00       4.15       12680          France
# 541908 2011-12-09 12:50:00       4.95       12680          France
#
#         Valid_InvoiceNo  Valid_StockCode  Valid_CustomerID
# Index
# 1                  True             True              True
# 5                  True             True              True
# 6                  True             True              True
# 7                  True             True              True
# 8                  True             True              True
# ...                 ...              ...               ...
# 541904             True             True              True
# 541905             True             True              True
# 541906             True             True              True
# 541907             True             True              True
# 541908             True             True              True
#
# [366179 rows x 11 columns]

# %%
df = df.drop(columns=['Valid_InvoiceNo', 'Valid_StockCode', 'Valid_CustomerID'])

# %%
df
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# Index
# 1         536365     71053                WHITE METAL LANTERN         6
# 5         536365     22752       SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730  GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633             HAND WARMER UNION JACK         6
# 8         536366     22632          HAND WARMER RED POLKA DOT         6
# ...          ...       ...                                ...       ...
# 541904    581587     22613        PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899       CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254      CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255    CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138      BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# Index
# 1      2010-12-01 08:26:00       3.39       17850  United Kingdom
# 5      2010-12-01 08:26:00       7.65       17850  United Kingdom
# 6      2010-12-01 08:26:00       4.25       17850  United Kingdom
# 7      2010-12-01 08:28:00       1.85       17850  United Kingdom
# 8      2010-12-01 08:28:00       1.85       17850  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85       12680          France
# 541905 2011-12-09 12:50:00       2.10       12680          France
# 541906 2011-12-09 12:50:00       4.15       12680          France
# 541907 2011-12-09 12:50:00       4.15       12680          France
# 541908 2011-12-09 12:50:00       4.95       12680          France
#
# [366179 rows x 8 columns]

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# ### Making sure **Country** column meet the rule: Country name. Nominal

# %%
df['Country'].value_counts()
# Out:
# Country
# United Kingdom          325525
# Germany                   8515
# France                    7767
# EIRE                      6750
# Spain                     2251
# Netherlands               2228
# Belgium                   1833
# Switzerland               1700
# Portugal                  1349
# Australia                 1192
# Norway                     988
# Italy                      736
# Channel Islands            713
# Cyprus                     567
# Finland                    538
# Sweden                     417
# Austria                    362
# Denmark                    344
# Japan                      339
# Poland                     311
# USA                        272
# Israel                     223
# Unspecified                218
# Singapore                  199
# Iceland                    162
# Greece                     135
# Canada                     126
# Malta                       97
# United Arab Emirates        66
# European Community          54
# RSA                         54
# Lebanon                     43
# Lithuania                   31
# Brazil                      28
# Czech Republic              23
# Bahrain                     13
# Saudi Arabia                10
# Name: count, dtype: int64

# %%
df.to_sql(name='retail_cleaned_data', con=conn, if_exists='replace', index=True, index_label='Id')
print('Successfully load cleaned data')
# Out:
# Successfully load cleaned data

# %%
alter_query = """ 

ALTER TABLE "retail_cleaned_data" ADD PRIMARY KEY ("Id");

"""
with conn.connect() as connection:
    connection.execute(text(alter_query))
    connection.commit()
